# %%
from selenium import webdriver
from selenium.webdriver.support.ui import Select
import pandas as pd
import time

# %% [markdown]
# ## Chrome

# %%
website = "https://www.adamchoi.co.uk/overs/detailed"
path = 'C:\webdrivers\chromedriver'
driver = webdriver.Chrome(path)
driver.get(website)
# Out:
# <ipython-input-2-4f49408d6119>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %%
driver.quit()

# %% [markdown]
# ## Firefox

# %%
website = "https://www.adamchoi.co.uk/overs/detailed"
driver = webdriver.Firefox(executable_path = r'C:\webdrivers\geckodriver.exe')
driver.get(website)
# Out:
# <ipython-input-16-a2dc6e728e88>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(executable_path = r'C:\webdrivers\geckodriver.exe')

# %% [markdown]
# ## Locate and click on a button

# %%
all_matches_button = driver.find_element_by_xpath('//label[@analytics-event="All matches"]')
all_matches_button.click()
# Out:
# <ipython-input-17-eab26dd2a24e>:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   all_matches_button = driver.find_element_by_xpath('//label[@analytics-event="All matches"]')

# %%
# select dropdown and select element inside by visible text
dropdown = Select(driver.find_element_by_id('country'))
dropdown.select_by_visible_text('Spain')
# implicit wait (useful in JavaScript driven websites when elements need seconds to load and avoid error "ElementNotVisibleException")
time.sleep(3)
# Out:
# <ipython-input-18-7c940a50fcc2>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dropdown = Select(driver.find_element_by_id('country'))

# %% [markdown]
# ## Select elements in the table

# %%
matches = driver.find_elements_by_tag_name('tr')
# Out:
# <ipython-input-10-8c3f72473c3e>:1: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   matches = driver.find_elements_by_tag_name('tr')

# %%
# storage data in lists
date = []
home_team = []
score = []
away_team = []

# %%
# looping through the matches list
for match in matches:
    date.append(match.find_element_by_xpath('./td[1]').text)
    home = match.find_element_by_xpath('./td[2]').text
    home_team.append(home)
    print(home)
    score.append(match.find_element_by_xpath('./td[3]').text)
    away_team.append(match.find_element_by_xpath('./td[4]').text)
# quit drive we opened at the beginning
driver.quit()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:393: UserWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   warnings.warn("find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead")
# Brentford
# Arsenal
# Man City
# Arsenal
# Burnley
# Arsenal
# Brighton
# Arsenal
# Arsenal
# Leicester
# Arsenal
# Liverpool
# Arsenal
# Man United
# Everton
# Arsenal
# Arsenal
# Leeds
# Norwich
# Arsenal
# Arsenal
# Wolves
# Arsenal
# Arsenal
# Watford
# Watford
# Aston Villa
# Aston Villa
# Chelsea
# Aston Villa
# Man United
# Tottenham
# Aston Villa
# Arsenal
# Aston Villa
# Southampton
# Aston Villa
# Crystal Palace
# Aston Villa
# Aston Villa
# Liverpool
# Norwich
# Aston Villa
# Brentford
# Aston Villa
# Everton
# Aston Villa
# Newcastle
# Aston Villa
# Brighton
# Aston Villa
# Brentford
# Crystal Palace
# Aston Villa
# Brentford
# Wolves
# Brentford
# West Ham
# Brentford
# Brentford
# Burnley
# Brentford
# Newcastle
# Brentford
# Tottenham
# Leeds
# Brentford
# Brighton
# Brentford
# Brentford
# Southampton
# Liverpool
# Brentford
# Brentford
# Man City
# Brentford
# Arsenal
# Brentford
# Norwich
# Burnley
# Brighton
# Brighton
# Brentford
# Brighton
# Crystal Palace
# Brighton
# Norwich
# Brighton
# Liverpool
# Brighton
# Aston Villa
# Brighton
# West Ham
# Southampton
# Brighton
# Brighton
# Chelsea
# Everton
# Brighton
# Brighton
# Leicester
