# %%
import scrapy
from scrapy.crawler import CrawlerProcess

# %%
class AudibleSpider(scrapy.Spider):
    name = 'audible'
    allowed_domains = ['www.audible.com']
    start_urls = ['https://www.audible.com/search/']

    def parse(self, response):
        # Getting the box that contains all the info we want (title, author, length)
        product_container = response.xpath('//div[@class="adbl-impression-container "]/li')

        # Looping through each product listed in the product_container box
        for product in product_container:
            book_title = product.xpath('.//h3[contains(@class, "bc-heading")]/a/text()').get()
            book_author = product.xpath('.//li[contains(@class, "authorLabel")]/span/a/text()').getall()
            book_length = product.xpath('.//li[contains(@class, "runtimeLabel")]/span/text()').get()

            # Return data extracted
            yield {
                'title': book_title,
                'author': book_author,
                'length': book_length,
            }

# %%
process = CrawlerProcess({
    'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'
})

process.crawl(AudibleSpider)
process.start()
# Out:
# 2022-03-07 03:57:27 [scrapy.utils.log] INFO: Scrapy 2.6.1 started (bot: scrapybot)
# 2022-03-07 03:57:27 [scrapy.utils.log] INFO: Versions: lxml 4.6.3.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 22.2.0, Python 3.8.8 (default, Apr 13 2021, 15:08:07) [MSC v.1916 32 bit (Intel)], pyOpenSSL 20.0.1 (OpenSSL 1.1.1k  25 Mar 2021), cryptography 3.4.7, Platform Windows-10-10.0.19041-SP0
# 2022-03-07 03:57:28 [scrapy.crawler] INFO: Overridden settings:
# {'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2022-03-07 03:57:28 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2022-03-07 03:57:29 [scrapy.extensions.telnet] INFO: Telnet Password: 0bfc8991197f23b3
# 2022-03-07 03:57:29 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2022-03-07 03:57:32 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-03-07 03:57:32 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-03-07 03:57:32 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-03-07 03:57:32 [scrapy.core.engine] INFO: Spider opened
# 2022-03-07 03:57:33 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-03-07 03:57:33 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2022-03-07 03:57:35 [filelock] DEBUG: Attempting to acquire lock 106613344 on C:\ProgramData\Anaconda3\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-03-07 03:57:35 [filelock] INFO: Lock 106613344 acquired on C:\ProgramData\Anaconda3\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-03-07 03:57:35 [filelock] DEBUG: Attempting to acquire lock 106614136 on C:\ProgramData\Anaconda3\lib\site-packages\tldextract\.suffix_cache/urls\62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2022-03-07 03:57:35 [filelock] INFO: Lock 106614136 acquired on C:\ProgramData\Anaconda3\lib\site-packages\tldextract\.suffix_cache/urls\62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2022-03-07 03:57:35 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): publicsuffix.org:443
# 2022-03-07 03:57:36 [urllib3.connectionpool] DEBUG: https://publicsuffix.org:443 "GET /list/public_suffix_list.dat HTTP/1.1" 200 None
# 2022-03-07 03:57:36 [filelock] DEBUG: Attempting to release lock 106614136 on C:\ProgramData\Anaconda3\lib\site-packages\tldextract\.suffix_cache/urls\62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2022-03-07 03:57:36 [filelock] INFO: Lock 106614136 released on C:\ProgramData\Anaconda3\lib\site-packages\tldextract\.suffix_cache/urls\62bf135d1c2f3d4db4228b9ecaf507a2.tldextract.json.lock
# 2022-03-07 03:57:36 [filelock] DEBUG: Attempting to release lock 106613344 on C:\ProgramData\Anaconda3\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-03-07 03:57:36 [filelock] INFO: Lock 106613344 released on C:\ProgramData\Anaconda3\lib\site-packages\tldextract\.suffix_cache/publicsuffix.org-tlds\de84b5ca2167d4c83e38fb162f2e8738.tldextract.json.lock
# 2022-03-07 03:57:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.audible.com/search/> (referer: None)
# 2022-03-07 03:57:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.audible.com/search/>
# {'title': 'Broken Reign', 'author': ['Ava Harrison'], 'length': 'Length: 9 hrs and 52 mins'}
# 2022-03-07 03:57:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.audible.com/search/>
# {'title': 'One Damn Thing After Another', 'author': ['William P. Barr'], 'length': 'Length: 22 hrs and 2 mins'}
# 2022-03-07 03:57:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.audible.com/search/>
# {'title': 'You, Happier', 'author': ['Daniel Amen'], 'length': 'Length: 10 hrs and 23 mins'}
# 2022-03-07 03:57:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.audible.com/search/>
# {'title': 'Taste', 'author': ['Melanie Harlow'], 'length': 'Length: 8 hrs and 15 mins'}
# 2022-03-07 03:57:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.audible.com/search/>
# {'title': 'Run, Rose, Run', 'author': ['James Patterson', 'Dolly Parton'], 'length': 'Length: 10 hrs and 19 mins'}
# 2022-03-07 03:57:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.audible.com/search/>
# {'title': 'The Great Reset', 'author': ['Glenn Beck', 'Justin Trask Haskins'], 'length': 'Length: 9 hrs and 57 mins'}
# 2022-03-07 03:57:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.audible.com/search/>
# {'title': 'The War of Two Queens', 'author': ['Jennifer L. Armentrout'], 'length': 'Length: 26 hrs and 38 mins'}
# 2022-03-07 03:57:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.audible.com/search/>
# {'title': 'The Lightning Rod', 'author': ['Brad Meltzer'], 'length': 'Length: 13 hrs and 43 mins'}
# 2022-03-07 03:57:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.audible.com/search/>
# {'title': 'The Kaiju Preservation Society', 'author': ['John Scalzi'], 'length': 'Length: Not Yet Known'}
# 2022-03-07 03:57:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.audible.com/search/>
# {'title': 'Anything', 'author': ['Dakota Krout'], 'length': 'Length: 12 hrs and 32 mins'}
# 2022-03-07 03:57:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.audible.com/search/>
# {'title': 'Oath of Loyalty', 'author': ['Vince Flynn', 'Kyle Mills'], 'length': 'Length: 8 hrs and 30 mins'}
# 2022-03-07 03:57:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.audible.com/search/>
# {'title': '12 Seconds in the Dark', 'author': ['John Mattingly'], 'length': 'Length: 4 hrs and 17 mins'}
# 2022-03-07 03:57:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.audible.com/search/>
# {'title': 'In the Blood', 'author': ['Jack Carr'], 'length': 'Length: 14 hrs and 30 mins'}
# 2022-03-07 03:57:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.audible.com/search/>
# {'title': 'The Broken Room', 'author': ['Peter Clines'], 'length': 'Length: 10 hrs and 50 mins'}
# 2022-03-07 03:57:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.audible.com/search/>
# {'title': 'The Match', 'author': ['Harlan Coben'], 'length': 'Length: 10 hrs and 4 mins'}
# 2022-03-07 03:57:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.audible.com/search/>
# {'title': 'The Golden Couple', 'author': ['Greer Hendricks', 'Sarah Pekkanen'], 'length': 'Length: 11 hrs and 3 mins'}
# 2022-03-07 03:57:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.audible.com/search/>
# {'title': 'He Who Fights with Monsters 5', 'author': ['Shirtaloon', 'Travis Deverell'], 'length': 'Length: 20 hrs and 47 mins'}
# 2022-03-07 03:57:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.audible.com/search/>
# {'title': 'Revealing Revelation', 'author': ['Amir Tsarfati', 'Rick Yohn'], 'length': 'Length: 7 hrs and 13 mins'}
# 2022-03-07 03:57:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.audible.com/search/>
# {'title': 'Dream Town', 'author': ['David Baldacci'], 'length': 'Length: 11 hrs'}
# 2022-03-07 03:57:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.audible.com/search/>
# {'title': 'Fairy Tale', 'author': ['Stephen King'], 'length': 'Length: 24 hrs'}
# 2022-03-07 03:57:37 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-03-07 03:57:37 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 242,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 102250,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 4.156235,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 3, 7, 7, 57, 37, 579681),
#  'httpcompression/response_bytes': 938352,
#  'httpcompression/response_count': 1,
#  'item_scraped_count': 20,
#  'log_count/DEBUG': 28,
#  'log_count/INFO': 14,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2022, 3, 7, 7, 57, 33, 423446)}
# 2022-03-07 03:57:37 [scrapy.core.engine] INFO: Spider closed (finished)
